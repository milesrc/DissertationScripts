# %%
'''Import packages for loading data, analysing, and plotting'''

import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xesmf as xe
# %matplotlib inline
import cartopy
import cartopy.crs as ccrs
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy.ma as ma
import math
import os
import matplotlib.colors as colors
import scipy
from matplotlib.projections import PolarAxes
import mpl_toolkits.axisartist.floating_axes as FA
import mpl_toolkits.axisartist.grid_finder as GF

# %%
#open files and define AMM variables

HadISST = xr.open_dataset('/Users/milesryan-cummings/Desktop/dissertation/data/HadISST/ACCESS-ESM1-5_HadISST.cvdp_data.1870-2016.nc', decode_times=False)
HadAMM= HadISST['amm_pattern_mon']

piControl= xr.open_dataset('/Users/milesryan-cummings/Desktop/dissertation/outputs/netcdf/amm_pattern_mon/PMIP4_piControl_amm_pattern_mon.nc', decode_times=False)
piControlAMM= piControl['amm_pattern_mon']

historical= xr.open_dataset('/Users/milesryan-cummings/Desktop/dissertation/outputs/netcdf/amm_pattern_mon/PMIP4_historical_amm_pattern_mon.nc', decode_times=False)
historicalAMM= historical['amm_pattern_mon']

# %%
HadAMM.std(dim=None, skipna=True)
# Out:
# <xarray.DataArray 'amm_pattern_mon' ()>
# array(0.1439109, dtype=float32)

# %%
piControlAMM.std(dim=None, skipna=True)
# Out:
# <xarray.DataArray 'amm_pattern_mon' ()>
# array(0.15966366)

# %%
historicalAMM.std(dim=None, skipna=True)
# Out:
# <xarray.DataArray 'amm_pattern_mon' ()>
# array(0.18528734)

# %%
#open files and define AMM variables

HadISST = xr.open_dataset('/Users/milesryan-cummings/Desktop/dissertation/data/HadISST/ACCESS-ESM1-5_HadISST.cvdp_data.1870-2016.nc', decode_times=False)
HadATL3= HadISST['atl3_pattern_mon']

piControl= xr.open_dataset('/Users/milesryan-cummings/Desktop/dissertation/outputs/netcdf/PMIP4_piControl_atl3_pattern_mon.nc', decode_times=False)
piControlATL3= piControl['atl3_pattern_mon']

historical= xr.open_dataset('/Users/milesryan-cummings/Desktop/dissertation/outputs/netcdf/PMIP4_historical_atl3_pattern_mon.nc', decode_times=False)
historicalATL3= historical['atl3_pattern_mon']

# %%
HadATL3.std(dim=None, skipna=True)
# Out:
# <xarray.DataArray 'atl3_pattern_mon' ()>
# array(0.15008788, dtype=float32)

# %%
piControlATL3.std(dim=None, skipna=True)
# Out:
# <xarray.DataArray 'atl3_pattern_mon' ()>
# array(0.14313803)

# %%
historicalATL3.std(dim=None, skipna=True)
# Out:
# <xarray.DataArray 'atl3_pattern_mon' ()>
# array(0.18452561)
