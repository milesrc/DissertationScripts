# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
#read in AMM PMIP4 csv files 

ammpmip4MH= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP4/ammtime-series_edit_PMIP4_MH.csv')
ammpmip4lgm= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP4/ammtime-series_edit_PMIP4_lgm.csv')
ammpmip4lig127k= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP4/ammtime-series_edit_PMIP4_lig127k.csv')
ammpmip41pctCO2= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP4/ammtime-series_edit_PMIP4_1pctCO2.csv')
ammpmip4abrupt4xCO2= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP4/ammtime-series_edit_PMIP4_abrupt4xCO2.csv')

#read in AMM PMIP3 csv files 

ammpmip3MH= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP3/ammtime-series_edit_PMIP3_MH.csv')
ammpmip3lgm= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP3/ammtime-series_edit_PMIP3_lgm.csv')
ammpmip3lig127k= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP3/ammtime-series_edit_PMIP3_lig127k.csv')
ammpmip31pctCO2= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP3/ammtime-series_edit_PMIP3_1pctCO2.csv')
ammpmip3abrupt4xCO2= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/amm/PMIP3/ammtime-series_edit_PMIP3_abrupt4xCO2.csv')

#read in ATL3 PMIP4 csv files 

atl3pmip4MH= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP4/atl3time-series-edit_PMIP4_MH.csv')
atl3pmip4lgm= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP4/atl3time-series-edit_PMIP4_lgm.csv')
atl3pmip4lig127k= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP4/atl3time-series-edit_PMIP4_lig127k.csv')
atl3pmip41pctCO2= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP4/atl3time-series-edit_PMIP4_1pctCO2.csv')
atl3pmip4abrupt4xCO2= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP4/atl3time-series-edit_PMIP4_abrupt4xCO2.csv')

#read in ATL3 PMIP3 csv files
atl3pmip3MH= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP3/atl3time-series-edit_PMIP3_MH.csv')
atl3pmip3lgm= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP3/atl3time-series-edit_PMIP3_lgm.csv')
atl3pmip3lig127k= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP3/atl3time-series-edit_PMIP3_lig127k.csv')
atl3pmip31pctCO2= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP3/atl3time-series-edit_PMIP3_1pctCO2.csv')
atl3pmip3abrupt4xCO2= pd.read_csv('/Users/milesryan-cummings/Desktop/dissertation/data/atl3/PMIP3/atl3time-series-edit_PMIP3_abrupt4xCO2.csv')

# %%
#bar charts

#AMM PMIP4

axes=ammpmip4MH.plot.bar(x = 'Model No.', y = ['midHolocene', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('AMM \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_AMM/PMIP4-amm-MH.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=ammpmip4lgm.plot.bar(x = 'Model No.', y = ['lgm', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('AMM \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_AMM/PMIP4-amm-lgm.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=ammpmip4lig127k.plot.bar(x = 'Model No.', y = ['lig127k', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('AMM \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_AMM/PMIP4-amm-lig127k.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=ammpmip41pctCO2.plot.bar(x = 'Model No.', y = ['1pctCO2', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('AMM \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_AMM/PMIP4-amm-1pctCO2.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=ammpmip4abrupt4xCO2.plot.bar(x = 'Model No.', y = ['abrupt4xCO2', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('AMM \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_AMM/PMIP4-amm-abrupt4xCO2.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

#AMM PMIP3

#axes=ammpmip3MH.plot.bar(x = 'Model No.', y = ['midHolocene', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('AMM \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_AMM/PMIP3-amm-MH.png',
            #dpi=400)

#axes=ammpmip3lgm.plot.bar(x = 'Model No.', y = ['lgm', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('AMM \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_AMM/PMIP3-amm-lgm.png',
            #dpi=400)

#axes=ammpmip3lig127k.plot.bar(x = 'Model No.', y = ['lig127k', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('AMM \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_AMM/PMIP3-amm-lig127k.png',
            #dpi=400)

#axes=ammpmip31pctCO2.plot.bar(x = 'Model No.', y = ['1pctCO2', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('AMM \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_AMM/PMIP3-amm-1pctCO2.png',
           # dpi=400)

#axes=ammpmip3abrupt4xCO2.plot.bar(x = 'Model No.', y = ['abrupt4xCO2', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('AMM \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_AMM/PMIP3-amm-abrupt4xCO2.png',
            #dpi=400)

#ATL3 PMIP4

axes=atl3pmip4MH.plot.bar(x = 'Model No.', y = ['midHolocene', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_ATL3/PMIP4-atl3-MH.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=atl3pmip4lgm.plot.bar(x = 'Model No.', y = ['lgm', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_ATL3/PMIP4-atl3-lgm.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=atl3pmip4lig127k.plot.bar(x = 'Model No.', y = ['lig127k', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_ATL3/PMIP4-atl3-lig127k.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=atl3pmip41pctCO2.plot.bar(x = 'Model No.', y = ['1pctCO2', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_ATL3/PMIP4-atl3-1pctCO2.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=atl3pmip4abrupt4xCO2.plot.bar(x = 'Model No.', y = ['abrupt4xCO2', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
fig=axes
fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_ATL3/PMIP4-atl3-abrupt4xCO2.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)


#ATL3 PMIP3

#axes=atl3pmip3MH.plot.bar(x = 'Model No.', y = ['midHolocene', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_ATL3/PMIP3-atl3-MH.png',
            #dpi=400)

#axes=atl3pmip3lgm.plot.bar(x = 'Model No.', y = ['lgm', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_ATL3/PMIP3-atl3-lgm.png',
            #dpi=400)

#axes=atl3pmip3lig127k.plot.bar(x = 'Model No.', y = ['lig127k', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_ATL3/PMIP3-atl3-lig127k.png',
            #dpi=400)

#axes=atl3pmip31pctCO2.plot.bar(x = 'Model No.', y = ['1pctCO2', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_ATL3/PMIP3-atl3-1pctCO2.png',
            #dpi=400)

#axes=atl3pmip3abrupt4xCO2.plot.bar(x = 'Model No.', y = ['abrupt4xCO2', 'piControl'], width=0.8, color= ["orange", "grey"], rot=0)
#fig=axes
#fig.set_ylabel('ATL3 \u03C3 $^\circ$C')
#plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP3_ATL3/PMIP3-atl3-abrupt4xCO2.png',
            #dpi=400)

# %%
#bar charts

#ATL3 %change PMIP4

axes=atl3pmip4MH.plot.bar(x = 'Model No.', y = 'ATL3', width=0.8, color= "orange", rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-MH-PC-AZM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=atl3pmip4lgm.plot.bar(x = 'Model No.', y = 'ATL3', width=0.8, color= "orange", rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-lgm-PC-AZM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=atl3pmip4lig127k.plot.bar(x = 'Model No.', y = 'ATL3', width=0.8, color= "orange", rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-lig127k-PC-AZM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=atl3pmip41pctCO2.plot.bar(x = 'Model No.', y = 'ATL3', width=0.8, color= "orange", rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-1pctCO2-PC-AZM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=atl3pmip4abrupt4xCO2.plot.bar(x = 'Model No.', y = 'ATL3', width=0.8, color= "orange", rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-abrupt4xCO2-PC-AZM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

# %%
#bar charts

#AMM %change PMIP4

axes=ammpmip4MH.plot.bar(x = 'Model No.', y = ['AMM'], width=0.8, color= ["orange"], rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-MH-PC-AMM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=ammpmip4lgm.plot.bar(x = 'Model No.', y = ['AMM'], width=0.8, color= ["orange"], rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-lgm-PC-AMM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=ammpmip4lig127k.plot.bar(x = 'Model No.', y = ['AMM'], width=0.8, color= ["orange"], rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-lig127k-PC-AMM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=ammpmip41pctCO2.plot.bar(x = 'Model No.', y = ['AMM'], width=0.8, color= ["orange"], rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-1pctCO2-PC-AMM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)

axes=ammpmip4abrupt4xCO2.plot.bar(x = 'Model No.', y = ['AMM'], width=0.8, color= ["orange"], rot=0, legend=None)
axes.axhline(y=0.0, color='black', linestyle='-', linewidth=0.5)
fig=axes
fig.set_ylabel('Change in \u03C3 (%)')
plt.savefig('/Users/milesryan-cummings/Documents/UCL/Dissertation/Drafts/4-Results/Figures/13_BarCharts/PMIP4_PC/PMIP4-abrupt4xCO2-PC-AMM.png',
            dpi=400,bbox_inches='tight', pad_inches = 0.01)
